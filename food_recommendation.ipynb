# %% [markdown]
# <a href="https://colab.research.google.com/github/2sneha5/2sneha5.github.io/blob/master/food_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np

df=pd.read_csv('/content/drive/MyDrive/db_food/food.csv')
train=pd.read_csv('/content/drive/MyDrive/db_food/food.csv')
df.columns = ['food_id','title','restaurant_id','price', 'num_orders', 'category', 'avg_rating', 'num_rating', 'tags']

df
# Out:
#      food_id         title  restaurant_id  price  num_orders category  \
# 0          1    Lala Maggi              1     30          35    maggi
# 1          2  Cheese Maggi              1     25          40    maggi
# 2          3  Masala Maggi              1     25          10    maggi
# 3          4     Veg Maggi              1     30          25    maggi
# 4          5  Paneer Tikka              1     60          50     meal
# ..       ...           ...            ...    ...         ...      ...
# 264      265     Til Pitha             11     30           0  dessert
# 265      266       Bebinca              3     60           0  dessert
# 266      267        Shufta              4     50           0  dessert
# 267      268     Mawa Bati              5     45           0  dessert
# 268      269        Pinaca             11     35           0  dessert
#
#      avg_rating  num_rating                 tags
# 0           3.9          10    vegetarian, spicy
# 1           3.8          15           vegetarian
# 2           3.0          10    vegetarian, spicy
# 3           2.5           5  vegetarian, healthy
# 4           4.6          30  vegetarian, healthy
# ..          ...         ...                  ...
# 264         3.4          10           vegetarian
# 265         2.3          17           vegetarian
# 266         2.6           3           vegetarian
# 267         2.5          10           vegetarian
# 268         2.5           4           vegetarian
#
# [269 rows x 9 columns]

# %%
# mean of average ratings of all items
C= df['avg_rating'].mean()
D= df['avg_rating'].median()
print("mean of avg rating ->",C)
print("median of avg rating ->",D)
# the minimum number of votes required to appear in recommendation list, i.e, 40% among 'num_rating'
m= df['num_rating'].quantile(0.4)

# items that qualify the criteria of minimum num of votes
qualified_items = df.copy().loc[df['num_rating'] >= m]

# Calculation of weighted rating based on the IMDB formula
def weighted_rating(x, m=m, C=C):
    v = x['num_rating']
    R = x['avg_rating']
    return (v/(v+m) * R) + (m/(m+v) * C)

# Applying weighted_rating to qualified items
qualified_items['score'] = qualified_items.apply(weighted_rating, axis=1)

# Shortlisting the top rated items and popular items
top_rated_items = qualified_items.sort_values('score', ascending=False)
pop_items= df.sort_values('num_orders', ascending=False)
# Out:
# mean of avg rating -> 3.6066914498141265
# median of avg rating -> 3.4

# %%
# Display results of demographic filtering
top_rated_items[['title', 'num_rating', 'avg_rating', 'score']].head()
pop_items[['title', 'num_orders']].head()
# Out:
#         title  num_rating  avg_rating     score
# 6      samosa          43         5.0  4.696005
# 178      Upma          42         5.0  4.690376
# 124  Panjeeri          42         5.0  4.690376
# 51    Ariselu          42         5.0  4.690376
# 103      Fara          42         5.0  4.690376
#            title  num_orders
# 6         samosa          90
# 4   Paneer Tikka          50
# 1   Cheese Maggi          40
# 5  Chicken Tikka          40
# 0     Lala Maggi          35

# %%
#Define the stopwords to remove and the stemming tool
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import SnowballStemmer
from subprocess import check_output
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", ':', ';', '(', ')', '[', ']', '{', '}'])
stemmer = SnowballStemmer('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Creating soup string for each item
def create_soup(x):            
    tags = x['tags'].lower().split(', ')
    tags.extend(x['title'].lower().split())
    tags.extend(x['category'].lower().split())
    return " ".join(sorted(set(tags), key=tags.index))

df['soup'] = df.apply(create_soup, axis=1)
df.head(10)
# Out:
#    food_id          title  restaurant_id  price  num_orders category  \
# 0        1     Lala Maggi              1     30          35    maggi
# 1        2   Cheese Maggi              1     25          40    maggi
# 2        3   Masala Maggi              1     25          10    maggi
# 3        4      Veg Maggi              1     30          25    maggi
# 4        5   Paneer Tikka              1     60          50     meal
# 5        6  Chicken Tikka              1     80          40     meal
# 6        7         samosa              2     40          90   snacks
# 7        8  onion kachori              2     35          10   snacks
# 8        9   bread pakoda              2     25          10   snacks
# 9       10  onion paratha              2     50          35   snacks
#
#    avg_rating  num_rating                    tags  \
# 0         3.9          10       vegetarian, spicy
# 1         3.8          15              vegetarian
# 2         3.0          10       vegetarian, spicy
# 3         2.5           5     vegetarian, healthy
# 4         4.6          30     vegetarian, healthy
# 5         4.2          28  nonveg, healthy, spicy
# 6         5.0          43     vegetarian, healthy
# 7         3.2          56     vegetarian, healthy
# 8         3.9          10     vegetarian, healthy
# 9         5.0          35       vegetarian, spicy
#
#                                       soup
# 0              vegetarian spicy lala maggi
# 1                  vegetarian cheese maggi
# 2            vegetarian spicy masala maggi
# 3             vegetarian healthy veg maggi
# 4     vegetarian healthy paneer tikka meal
# 5  nonveg healthy spicy chicken tikka meal
# 6         vegetarian healthy samosa snacks
# 7  vegetarian healthy onion kachori snacks
# 8   vegetarian healthy bread pakoda snacks
# 9    vegetarian spicy onion paratha snacks

# %%
#Preprocess the text in training and testing
import nltk
nltk.download('punkt')
processed_train = []
X_text_train=df['title'].values
X_text_test=df['tags'].values
for doc in X_text_train:
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    stemmed = [stemmer.stem(word) for word in filtered]
    processed_train.append(stemmed)
    
processed_test = []
for doc in X_text_test:
    tokens = word_tokenize(doc)
    filtered = [word for word in tokens if word not in stop_words]
    stemmed = [stemmer.stem(word) for word in filtered]
    processed_test.append(stemmed)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer
count = CountVectorizer(stop_words='english')

# df['soup']
count_matrix = count.fit_transform(df['soup'])
count_matrix
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(count_matrix, count_matrix)

indices_from_title = pd.Series(df.index, index=df['title'])
indices_from_food_id = pd.Series(df.index, index=df['food_id'])
# Out:
# <269x335 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1146 stored elements in Compressed Sparse Row format>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
X_train, X_test, y_train, y_test = train_test_split(df['title'],df['soup'],test_size=0.33,random_state=8675309)
X_train

X_test.shape
y_test.shape
y_train.shape
print("--->",X_train.shape)
# Out:
# 115                    Misi roti
# 224                Veg Kolhapuri
# 262                     Red Rice
# 10                  idli sambhar
# 200                       Handwo
#                  ...
# 18                   Gulab jamun
# 232    Turiya Patra Vatana sabji
# 255                  Koldil Duck
# 140               Bisi bele bath
# 1                   Cheese Maggi
# Name: title, Length: 180, dtype: object
# (89,)
# (89,)
# (180,)
# ---> (180,)

# %%
X_train_cv = count.transform(df['soup'])

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(X_train)

X_train_tfidf = tfidf.transform(X_train)
X_test_tfidf = tfidf.transform(X_test)
test_tfidf = tfidf.transform(df['soup'])

rf = RandomForestClassifier()
rf.fit(X_train_tfidf, y_train)
print(rf.score(X_test_tfidf, y_test))
predictions = rf.predict(X_test_tfidf)
# print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# TfidfVectorizer(stop_words='english')
# RandomForestClassifier()
# 0.0
#                                                   precision    recall  f1-score   support
#
#            non vegetarian alu pitika main course       0.00      0.00      0.00       0.0
#              non vegetarian beef fry main course       0.00      0.00      0.00       0.0
#            non vegetarian black rice main course       0.00      0.00      0.00       0.0
#            non vegetarian bombil fry main course       0.00      0.00      0.00       1.0
#        non vegetarian butter chicken main course       0.00      0.00      0.00       1.0
#  non vegetarian chicken tikka masala main course       0.00      0.00      0.00       1.0
#             non vegetarian chicken tikka starter       0.00      0.00      0.00       0.0
#   non vegetarian chingri malai curry main course       0.00      0.00      0.00       0.0
#                 non vegetarian galho main course       0.00      0.00      0.00       1.0
#           non vegetarian kolim jawla main course       0.00      0.00      0.00       1.0
#             non vegetarian konir dom main course       0.00      0.00      0.00       1.0
#           non vegetarian kumol sawul main course       0.00      0.00      0.00       1.0
#           non vegetarian pork bharta main course       0.00      0.00      0.00       1.0
#      non vegetarian tandoori chicken main course       0.00      0.00      0.00       1.0
#       non vegetarian tandoori fish tikka starter       0.00      0.00      0.00       1.0
#                     vegetarian adhirasam dessert       0.00      0.00      0.00       1.0
#                vegetarian aloo matar main course       0.00      0.00      0.00       0.0
#                vegetarian aloo methi main course       0.00      0.00      0.00       1.0
#         vegetarian aloo shimla mirch main course       0.00      0.00      0.00       1.0
#                vegetarian aloo tikki main course       0.00      0.00      0.00       1.0
#                      vegetarian amti main course       0.00      0.00      0.00       1.0
#                        vegetarian anarsa dessert       0.00      0.00      0.00       1.0
#                            vegetarian attu snack       0.00      0.00      0.00       1.0
#                  vegetarian bandar laddu dessert       0.00      0.00      0.00       1.0
#                       vegetarian bebinca dessert       0.00      0.00      0.00       1.0
#            vegetarian bengena pitika main course       0.00      0.00      0.00       1.0
#                    vegetarian bhakri main course       0.00      0.00      0.00       1.0
#                vegetarian bora sawul main course       0.00      0.00      0.00       0.0
#                vegetarian brown rice main course       0.00      0.00      0.00       1.0
#                         vegetarian chakali snack       0.00      0.00      0.00       1.0
#              vegetarian chana masala main course       0.00      0.00      0.00       1.0
#                          vegetarian chevdo snack       0.00      0.00      0.00       1.0
#                 vegetarian chhena jalebi dessert       0.00      0.00      0.00       1.0
#                       vegetarian chorafali snack       0.00      0.00      0.00       1.0
#       vegetarian currivepillai sadam main course       0.00      0.00      0.00       1.0
#         vegetarian daal baati churma main course       0.00      0.00      0.00       0.0
#               vegetarian daal dhokli main course       0.00      0.00      0.00       1.0
#                  vegetarian dalithoy main course       0.00      0.00      0.00       1.0
#                 vegetarian dharwad pedha dessert       0.00      0.00      0.00       1.0
#                          vegetarian dhokla snack       0.00      0.00      0.00       1.0
#                       vegetarian dhondas dessert       0.00      0.00      0.00       1.0
#              vegetarian double ka meetha dessert       0.00      0.00      0.00       1.0
#                   vegetarian dudhi halwa dessert       0.00      0.00      0.00       1.0
#                      vegetarian farsi puri snack       0.00      0.00      0.00       1.0
#               vegetarian gatta curry main course       0.00      0.00      0.00       1.0
#           vegetarian healthy bread pakoda snacks       0.00      0.00      0.00       0.0
#           vegetarian healthy idli sambhar snacks       0.00      0.00      0.00       0.0
#             vegetarian healthy paneer tikka meal       0.00      0.00      0.00       0.0
#                 vegetarian healthy samosa snacks       0.00      0.00      0.00       1.0
#                     vegetarian healthy veg maggi       0.00      0.00      0.00       1.0
#                            vegetarian idli snack       0.00      0.00      0.00       1.0
#                        vegetarian jalebi dessert       0.00      0.00      0.00       0.0
#                vegetarian jeera aloo main course       0.00      0.00      0.00       0.0
#              vegetarian kadhi pakoda main course       0.00      0.00      0.00       1.0
#                     vegetarian kajjikaya dessert       0.00      0.00      0.00       1.0
#                           vegetarian kanji snack       0.00      0.00      0.00       1.0
#                    vegetarian kansar main course       0.00      0.00      0.00       1.0
#             vegetarian karela bharta main course       0.00      0.00      0.00       0.0
#            vegetarian keerai masiyal main course       0.00      0.00      0.00       1.0
#              vegetarian keerai sadam main course       0.00      0.00      0.00       0.0
#                          vegetarian khaman snack       0.00      0.00      0.00       1.0
#                          vegetarian khichu snack       0.00      0.00      0.00       1.0
#                   vegetarian khorisa main course       0.00      0.00      0.00       1.0
#              vegetarian kuzhakkattai main course       0.00      0.00      0.00       1.0
#                  vegetarian kuzhambu main course       0.00      0.00      0.00       1.0
#                    vegetarian laapsi main course       0.00      0.00      0.00       1.0
#                         vegetarian laddu dessert       0.00      0.00      0.00       0.0
#                      vegetarian lyangcha dessert       0.00      0.00      0.00       1.0
#                      vegetarian mag dhokli snack       0.00      0.00      0.00       0.0
#                   vegetarian mahim halwa dessert       0.00      0.00      0.00       0.0
#                       vegetarian malapua dessert       0.00      0.00      0.00       1.0
#                     vegetarian masala dosa snack       0.00      0.00      0.00       0.0
#                     vegetarian mawa bati dessert       0.00      0.00      0.00       1.0
#                         vegetarian modak dessert       0.00      0.00      0.00       1.0
#                      vegetarian naan main course       0.00      0.00      0.00       1.0
#                       vegetarian namakpara snack       0.00      0.00      0.00       1.0
#                     vegetarian nankhatai dessert       0.00      0.00      0.00       0.0
#                   vegetarian pachadi main course       0.00      0.00      0.00       1.0
#                   vegetarian pakhala main course       0.00      0.00      0.00       1.0
#      vegetarian paneer butter masala main course       0.00      0.00      0.00       1.0
#       vegetarian paneer tikka masala main course       0.00      0.00      0.00       0.0
#                       vegetarian pani puri snack       0.00      0.00      0.00       0.0
#                           vegetarian papad snack       0.00      0.00      0.00       1.0
#                vegetarian paravannam main course       0.00      0.00      0.00       1.0
#                           vegetarian patra snack       0.00      0.00      0.00       1.0
#                    vegetarian pattor main course       0.00      0.00      0.00       1.0
#                 vegetarian pav bhaji main course       0.00      0.00      0.00       1.0
#                         vegetarian petha dessert       0.00      0.00      0.00       1.0
#               vegetarian pindi chana main course       0.00      0.00      0.00       1.0
#                        vegetarian pongal dessert       0.00      0.00      0.00       1.0
#                vegetarian puli sadam main course       0.00      0.00      0.00       1.0
#                vegetarian puri bhaji main course       0.00      0.00      0.00       0.0
#              vegetarian qubani ka meetha dessert       0.00      0.00      0.00       0.0
#                         vegetarian rabri dessert       0.00      0.00      0.00       1.0
#                      vegetarian rasabali dessert       0.00      0.00      0.00       1.0
#                     vegetarian rasam main course       0.00      0.00      0.00       1.0
#                          vegetarian samosa snack       0.00      0.00      0.00       0.0
#                       vegetarian sandesh dessert       0.00      0.00      0.00       1.0
#                   vegetarian sandige main course       0.00      0.00      0.00       1.0
#              vegetarian shahi paneer main course       0.00      0.00      0.00       0.0
#                   vegetarian shahi tukra dessert       0.00      0.00      0.00       1.0
#                        vegetarian sheera dessert       0.00      0.00      0.00       1.0
#                        vegetarian shufta dessert       0.00      0.00      0.00       1.0
#                       vegetarian singori dessert       0.00      0.00      0.00       1.0
#                   vegetarian sohan halwa dessert       0.00      0.00      0.00       1.0
#                    vegetarian spicy masala maggi       0.00      0.00      0.00       1.0
#                         vegetarian surnoli snack       0.00      0.00      0.00       1.0
#                    vegetarian sutar feni dessert       0.00      0.00      0.00       1.0
#              vegetarian thayir sadam main course       0.00      0.00      0.00       1.0
# vegetarian turiya patra vatana sabji main course       0.00      0.00      0.00       0.0
#                   vegetarian undhiyu main course       0.00      0.00      0.00       1.0
#                    vegetarian unni appam dessert       0.00      0.00      0.00       1.0
#                            vegetarian upma snack       0.00      0.00      0.00       1.0
#                         vegetarian uttapam snack       0.00      0.00      0.00       1.0
#             vegetarian veg kolhapuri main course       0.00      0.00      0.00       0.0
#        vegetarian vegetable jalfrezi main course       0.00      0.00      0.00       1.0
#         vegetarian,healthy daal puri main course       0.00      0.00      0.00       1.0
#
#                                         accuracy                           0.00      89.0
#                                        macro avg       0.00      0.00      0.00      89.0
#                                     weighted avg       0.00      0.00      0.00      89.0
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Function that takes in food title or food id as input and outputs most similar dishes 
def get_recommendations(title="", cosine_sim=cosine_sim, idx=-1):
    # Get the index of the item that matches the title
    if idx == -1 and title != "":
        idx = indices_from_title[title]

    # Get the pairwsie similarity scores of all dishes with that dish
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the dishes based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the 10 most similar dishes
    sim_scores = sim_scores[1:3]

    # Get the food indices
    food_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar dishes
    return food_indices

# %%
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer

my_stop_words = text.ENGLISH_STOP_WORDS.union(df['soup'])

vectorizer = TfidfVectorizer(ngram_range=(1,1), stop_words=my_stop_words)

X = vectorizer.fit_transform(df['soup'])

idf_values = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))

# printing the tfidf vectors
print(X)

# printing the vocabulary
print(vectorizer.vocabulary_)
# Out:
#   (0, 182)	0.5389964527121502
#   (0, 171)	0.6379900453000649
#   (0, 302)	0.5389964527121502
#   (0, 332)	0.10924445077649832
#   (1, 45)	0.7574307968428433
#   (1, 182)	0.639904204902158
#   (1, 332)	0.12969655563102792
#   (2, 189)	0.5354618849010933
#   (2, 182)	0.5911534360885646
#   (2, 302)	0.5911534360885646
#   (2, 332)	0.11981569104059384
#   (3, 330)	0.6229696677622945
#   (3, 106)	0.4916601171769017
#   (3, 182)	0.5962988579221642
#   (3, 332)	0.1208585713404484
#   (4, 194)	0.53758489773278
#   (4, 316)	0.5013285394791389
#   (4, 223)	0.5013285394791389
#   (4, 106)	0.4432493041037016
#   (4, 332)	0.10895835511170089
#   (5, 49)	0.3747019913607045
#   (5, 213)	0.46823385930474504
#   (5, 194)	0.42474401736748024
#   (5, 316)	0.3960979908055121
#   (5, 106)	0.35020978251872176
#   :	:
#   (262, 270)	0.6272257692529298
#   (262, 58)	0.20829444955989568
#   (262, 184)	0.20829444955989568
#   (262, 332)	0.12168427180751258
#   (263, 297)	0.9124353788710969
#   (263, 58)	0.26744276242774984
#   (263, 184)	0.26744276242774984
#   (263, 332)	0.15623833407453483
#   (264, 318)	0.7179270251784662
#   (264, 245)	0.6336584497063805
#   (264, 67)	0.260663424165334
#   (264, 332)	0.12293223717360537
#   (265, 17)	0.9280183863882703
#   (265, 67)	0.33694295074659103
#   (265, 332)	0.15890664702110904
#   (266, 296)	0.9280183863882703
#   (266, 67)	0.33694295074659103
#   (266, 332)	0.15890664702110904
#   (267, 16)	0.680233387189431
#   (267, 193)	0.680233387189431
#   (267, 67)	0.2469776978966677
#   (267, 332)	0.11647787192101972
#   (268, 243)	0.9280183863882703
#   (268, 67)	0.33694295074659103
#   (268, 332)	0.15890664702110904
# {'vegetarian': 332, 'spicy': 302, 'lala': 171, 'maggi': 182, 'cheese': 45, 'masala': 189, 'healthy': 106, 'veg': 330, 'paneer': 223, 'tikka': 316, 'meal': 194, 'nonveg': 213, 'chicken': 49, 'samosa': 282, 'snacks': 300, 'onion': 215, 'kachori': 120, 'bread': 35, 'pakoda': 220, 'paratha': 231, 'idli': 109, 'sambhar': 281, 'bataka': 14, 'poha': 249, 'biryani': 29, 'raita': 262, 'puri': 257, 'bhaji': 21, 'balu': 11, 'shahi': 290, 'dessert': 67, 'boondi': 33, 'gajar': 87, 'ka': 117, 'halwa': 101, 'ghevar': 92, 'gulab': 98, 'jamun': 113, 'imarti': 110, 'jalebi': 111, 'kaju': 124, 'katli': 130, 'kalakand': 126, 'kheer': 140, 'laddu': 169, 'lassi': 172, 'nankhatai': 210, 'petha': 241, 'phirni': 242, 'rabri': 261, 'sheera': 293, 'singori': 298, 'sohan': 301, 'papdi': 230, 'chhena': 47, 'kheeri': 141, 'poda': 248, 'cham': 40, 'sagar': 279, 'ledikeni': 174, 'lyangcha': 178, 'malapua': 188, 'mihidana': 197, 'misti': 201, 'doi': 73, 'pantua': 227, 'pithe': 246, 'rasabali': 265, 'ras': 264, 'malai': 187, 'rasgulla': 267, 'sandesh': 283, 'adhirasam': 0, 'ariselu': 6, 'bandar': 12, 'chikki': 50, 'dharwad': 68, 'pedha': 239, 'double': 77, 'meetha': 195, 'gavvalu': 90, 'kakinada': 125, 'khaja': 134, 'kuzhi': 167, 'paniyaram': 225, 'mysore': 206, 'pak': 218, 'obbattu': 214, 'holige': 107, 'main': 184, 'course': 58, 'palathalikalu': 222, 'poornalu': 251, 'pongal': 250, 'pootharekulu': 252, 'qubani': 260, 'sheer': 292, 'korma': 156, 'unni': 322, 'appam': 5, 'kajjikaya': 123, 'anarsa': 4, 'basundi': 13, 'dhondas': 71, 'doodhpak': 75, 'mahim': 183, 'modak': 202, 'shankarpali': 291, 'shrikhand': 295, 'sutar': 307, 'feni': 84, 'non': 212, 'maach': 179, 'jhol': 116, 'pork': 254, 'bharta': 24, 'chak': 38, 'hao': 104, 'galho': 88, 'aloo': 1, 'gobi': 94, 'tikki': 317, 'matar': 192, 'methi': 196, 'shimla': 294, 'mirch': 198, 'bhatura': 25, 'bhindi': 27, 'butter': 37, 'chana': 41, 'chapati': 42, 'razala': 268, 'starter': 303, 'chole': 53, 'bhature': 26, 'daal': 62, 'baati': 9, 'churma': 55, 'dal': 65, 'makhani': 185, 'tadka': 308, 'dum': 80, 'snack': 299, 'fara': 82, 'kadai': 121, 'kadhi': 122, 'karela': 129, 'khichdi': 143, 'kofta': 147, 'kulfi': 162, 'falooda': 81, 'lauki': 173, 'ke': 131, 'kofte': 148, 'ki': 146, 'subji': 304, 'litti': 176, 'chokha': 52, 'makki': 186, 'di': 72, 'roti': 272, 'sarson': 285, 'da': 61, 'saag': 274, 'misi': 200, 'mushroom': 204, 'pyaza': 259, 'naan': 208, 'navrattan': 211, 'palak': 221, 'pani': 224, 'panjeeri': 226, 'papad': 228, 'pattor': 235, 'pindi': 244, 'rajma': 263, 'chaval': 43, 'rongi': 271, 'sattu': 286, 'tukra': 319, 'vegetable': 331, 'jalfrezi': 112, 'tandoori': 310, 'fish': 85, 'attu': 7, 'avial': 8, 'bisi': 30, 'bele': 19, 'bath': 15, 'currivepillai': 59, 'sadam': 278, 'dosa': 76, 'idiappam': 108, 'kanji': 127, 'kaara': 118, 'kozhambu': 161, 'keerai': 132, 'kootu': 155, 'masiyal': 190, 'poriyal': 253, 'beef': 18, 'fry': 86, 'kos': 157, 'koshambri': 158, 'kothamali': 160, 'kuzhakkattai': 165, 'kuzhambu': 166, 'pachadi': 217, 'papadum': 229, 'paravannam': 232, 'payasam': 237, 'paruppu': 233, 'pesarattu': 240, 'puli': 256, 'rasam': 266, 'puttu': 258, 'sambar': 280, 'sandige': 284, 'sevai': 289, 'thayir': 313, 'theeyal': 314, 'uttapam': 324, 'vada': 325, 'varuval': 328, 'upma': 323, 'amti': 3, 'zunka': 334, 'kolim': 151, 'jawla': 114, 'saath': 275, 'bajri': 10, 'rotlo': 273, 'coconut': 56, 'vadi': 327, 'bhakri': 22, 'bombil': 32, 'chakali': 39, 'chevdo': 46, 'chorafali': 54, 'copra': 57, 'paak': 216, 'dhokli': 70, 'kutchi': 164, 'dabeli': 63, 'dahi': 64, 'dalithoy': 66, 'dhokla': 69, 'dudhi': 79, 'gatta': 89, 'curry': 60, 'gud': 97, 'ghooghra': 93, 'handwo': 103, 'halvasan': 100, 'jeera': 115, 'kansar': 128, 'keri': 133, 'khakhra': 135, 'khandvi': 138, 'kombdi': 152, 'vade': 326, 'laapsi': 168, 'koshimbir': 159, 'na': 207, 'gota': 96, 'mohanthal': 203, 'muthiya': 205, 'patra': 234, 'pav': 236, 'sabudana': 277, 'khichadi': 142, 'sev': 288, 'khamani': 137, 'tameta': 309, 'namakpara': 209, 'sukhdi': 305, 'surnoli': 306 ...
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:401: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['adhirasam', 'aloo', 'alu', 'amti', 'anarsa', 'appam', 'ariselu', 'attu', 'avial', 'baati', 'bajri', 'balu', 'bandar', 'basundi', 'bataka', 'bath', 'bati', 'bebinca', 'beef', 'bele', 'bengena', 'bhaji', 'bhakri', 'bhape', 'bharta', 'bhatura', 'bhature', 'bhindi', 'bilahi', 'biryani', 'bisi', 'black', 'bombil', 'boondi', 'bora', 'bread', 'brown', 'butter', 'chak', 'chakali', 'cham', 'chana', 'chapati', 'chaval', 'cheera', 'cheese', 'chevdo', 'chhena', 'chholar', 'chicken', 'chikki', 'chingri', 'chokha', 'chole', 'chorafali', 'churma', 'coconut', 'copra', 'course', 'currivepillai', 'curry', 'da', 'daal', 'dabeli', 'dahi', 'dal', 'dalithoy', 'dessert', 'dharwad', 'dhokla', 'dhokli', 'dhondas', 'di', 'doi', 'dom', 'doodhpak', 'dosa', 'double', 'duck', 'dudhi', 'dum', 'falooda', 'fara', 'farsi', 'feni', 'fish', 'fry', 'gajar', 'galho', 'gatta', 'gavvalu', 'gheela', 'ghevar', 'ghooghra', 'gobi', 'goja', 'gota', 'gud', 'gulab', 'guri', 'halvasan', 'halwa', 'hando', 'handwo', 'hao', 'haq', 'healthy', 'holige', 'idiappam', 'idli', 'imarti', 'jalebi', 'jalfrezi', 'jamun', 'jawla', 'jeera', 'jhol', 'ka', 'kaara', 'kabiraji', 'kachori', 'kadai', 'kadhi', 'kajjikaya', 'kaju', 'kakinada', 'kalakand', 'kanji', 'kansar', 'karela', 'katli', 'ke', 'keerai', 'keri', 'khaja', 'khakhra', 'khaman', 'khamani', 'khandvi', 'khar', 'kheer', 'kheeri', 'khichadi', 'khichdi', 'khichu', 'khorisa', 'ki', 'kofta', 'kofte', 'koldil', 'kolhapuri', 'kolim', 'kombdi', 'koni', 'konir', 'kootu', 'korma', 'kos', 'koshambri', 'koshimbir', 'kothamali', 'kozhambu', 'kulfi', 'kumol', 'kutchi', 'kuzhakkattai', 'kuzhambu', 'kuzhi', 'laapsi', 'laddu', 'ladoo', 'lala', 'lassi', 'lauki', 'ledikeni', 'lilva', 'litti', 'luchi', 'lyangcha', 'maach', 'maas', 'mag', 'maggi', 'mahim', 'main', 'makhani', 'makki', 'malai', 'malapua', 'masala', 'masiyal', 'masor', 'matar', 'mawa', 'meal', 'meetha', 'methi', 'mihidana', 'mirch', 'mishti', 'misi', 'misti', 'modak', 'mohanthal', 'mushroom', 'muthiya', 'mysore', 'na', 'naan', 'namakpara', 'nankhatai', 'navrattan', 'non', 'nonveg', 'obbattu', 'onion', 'paak', 'pachadi', 'pak', 'pakhala', 'pakoda', 'palak', 'palathalikalu', 'paneer', 'pani', 'paniyaram', 'panjeeri', 'pantua', 'papad', 'papadum', 'papdi', 'paratha', 'paravannam', 'paruppu', 'patra', 'pattor', 'pav', 'payasam', 'payokh', 'pedha', 'pesarattu', 'petha', 'phirni', 'pinaca', 'pindi', 'pitha', 'pithe', 'pitika', 'poda', 'poha', 'pongal', 'poornalu', 'pootharekulu', 'poriyal', 'pork', 'prawn', 'puli', 'puri', 'puttu', 'pyaza', 'qubani', 'rabri', 'raita', 'rajma', 'ras', 'rasabali', 'rasam', 'rasgulla', 'razala', 'red', 'rice', 'rongi', 'roti', 'rotlo', 'saag', 'saath', 'sabji', 'sabudana', 'sadam', 'sagar', 'sambar', 'sambhar', 'samosa', 'sandesh', 'sandige', 'sarson', 'sattu', 'sawul', 'sev', 'sevai', 'shahi', 'shankarpali', 'sheer', 'sheera', 'shimla', 'shrikhand', 'shufta', 'shukto', 'singori', 'snack', 'snacks', 'sohan', 'spicy', 'starter', 'subji', 'sukhdi', 'surnoli', 'sutar', 'tadka', 'tameta', 'tandoori', 'tenga', 'thalipeeth', 'thayir', 'theeyal', 'thepla', 'tikka', 'tikki', 'til', 'tukra', 'turiya', 'undhiyu', 'unni', 'upma', 'uttapam', 'vada', 'vade', 'vadi', 'varuval', 'vatana', 'veg', 'vegetable', 'vegetarian', 'vindaloo', 'zunka'] not in stop_words.
#   % sorted(inconsistent)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
df.loc[get_recommendations(title="Paratha")]
# Out:
#     food_id      title  restaurant_id  price  num_orders     category  \
# 98       99  Daal puri              7     30           0  main course
# 87       88    Bhatura              4     20           0  main course
#
#     avg_rating  num_rating                tags  \
# 98         3.8          35  vegetarian,healthy
# 87         2.3          35          vegetarian
#
#                                         soup
# 98  vegetarian,healthy daal puri main course
# 87            vegetarian bhatura main course

# %%
# fetch few past orders of a user, based on which personalized recommendations are to be made
def get_latest_user_orders(user_id, orders, num_orders=3):
    counter = num_orders
    order_indices = []
    for index, row in orders[['user_id']].iterrows():
        if row.user_id == user_id:
            counter = counter -1
            order_indices.append(index)
        if counter == 0:
            break
    return order_indices

# utility function that returns a DataFrame given the food_indices to be recommended
def get_recomms_df(food_indices, df1, columns, comment):
    row = 0
    df = pd.DataFrame(columns=columns)
    
    for i in food_indices:
        df.loc[row] = df1[['title', 'restaurant_id', 'price']].loc[i]
        df.loc[row].comment = comment
        row = row+1
    return df

# return food_indices for accomplishing personalized recommendation using Count Vectorizer
def personalised_recomms(orders, df1, user_id, columns, comment="based on your past orders"):
    order_indices = get_latest_user_orders(user_id, orders)
    food_ids = []
    food_indices = []
    recomm_indices = []
    for i in order_indices:
        food_ids.append(orders.loc[i].food_id)
    for i in food_ids:
        food_indices.append(indices_from_food_id[i])
    for i in food_indices:
        recomm_indices.extend(get_recommendations(idx=i))
    return get_recomms_df(set(recomm_indices), df1, columns, comment)

# Simply fetch new items added by vendor or today's special at restaurant
def get_new_and_specials_recomms(new_and_specials, users, df, restaurant_id, columns, comment="new/today's special item  in your restaurant"):
    food_indices = []
    for index, row in new_and_specials[['restaurant_id']].iterrows():
        if row.restaurant_id == restaurant_id:
            food_indices.append(indices_from_food_id[new_and_specials.loc[index].food_id])
    return get_recomms_df(set(food_indices), df, columns, comment)

# utility function to get the restaurant given a user id
def get_user_home_restaurant(users, user_id):
    for index, row in users[['user_id']].iterrows():
        if row.user_id == user_id:
            return users.loc[index].home_parcel
    return -1

# fetch items from previously calculated top_rated_items list
def get_top_rated_items(top_rated_items, df1, columns, comment="top rated items across restaurants"):
    food_indices = []
    for index, row in top_rated_items.iterrows():
        food_indices.append(indices_from_food_id[top_rated_items.loc[index].food_id])
    return get_recomms_df(food_indices, df1, columns, comment)

# fetch items from previously calculated pop_items list
def get_popular_items(pop_items, df1, columns, comment="most popular items across restaurants"):
    food_indices = []
    for index, row in pop_items.iterrows():
        food_indices.append(indices_from_food_id[pop_items.loc[index].food_id])
    return get_recomms_df(food_indices, df1, columns, comment)

# %%
orders = pd.read_csv('/content/drive/MyDrive/db_food/orders.csv')
new_and_specials = pd.read_csv('/content/drive/MyDrive/db_food/new_and_specials.csv')
users = pd.read_csv('/content/drive/MyDrive/db_food/users.csv')

columns = ['title', 'restaurant_id', 'price', 'comment']
current_user = 2
current_restaurant = get_user_home_restaurant(users, current_user)
print("personalized recommendataions")
personalised_recomms(orders, df, current_user, columns)
print("new and special dishes of restaurant")
get_new_and_specials_recomms(new_and_specials, users, df, current_restaurant, columns)
# print("top rated items in restaurants")
# get_top_rated_items(top_rated_items, df, columns)
print("popular items")
get_popular_items(pop_items, df, columns).head(3)
# Out:
# personalized recommendataions
#                  title restaurant_id price                    comment
# 0         Cheese Maggi             1    25  based on your past orders
# 1         Masala Maggi             1    25  based on your past orders
# 2         Paneer Tikka             1    60  based on your past orders
# 3        Chicken Tikka             1    80  based on your past orders
# 4   biryani with raita             2   100  based on your past orders
# 5  Paneer tikka masala             8    40  based on your past orders
# new and special dishes of restaurant
#           title restaurant_id price  \
# 0  Cheese Maggi             1    25
# 1       Khichdi             7    20
#
#                                         comment
# 0  new/today's special item  in your restaurant
# 1  new/today's special item  in your restaurant
# top rated items in restaurants
#            title restaurant_id price                             comment
# 0         samosa             2    40  top rated items across restaurants
# 1           Upma             8    20  top rated items across restaurants
# 2       Panjeeri             2    25  top rated items across restaurants
# 3        Ariselu             1    75  top rated items across restaurants
# 4           Fara             6    60  top rated items across restaurants
# ..           ...           ...   ...                                 ...
# 188        Patra            10    40  top rated items across restaurants
# 189      Bhatura             4    20  top rated items across restaurants
# 190   Cheera Doi            10    35  top rated items across restaurants
# 191  bataka poha             3    25  top rated items across restaurants
# 192     Halvasan             9   100  top rated items across restaurants
#
# [193 rows x 4 columns]
# popular items
#           title restaurant_id price                                comment
# 0        samosa             2    40  most popular items across restaurants
# 1  Paneer Tikka             1    60  most popular items across restaurants
# 2  Cheese Maggi             1    25  most popular items across restaurants
